# %%
# %pip install pandas numpy matplotlib
# Out:
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.5.0-cp314-cp314-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 1.2 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/9.9 MB 1.0 MB/s eta 0:00:10
#    ---- ----------------------------------- 1.0/9.9 MB 1.3 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.3/9.9 MB 1.3 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/9.9 MB 1.3 MB/s eta 0:00:07
#    ------- -------------------------------- 1.8/9.9 MB 1.3 MB/s eta 0:00:07
#    -------- ------------------------------- 2.1/9.9 MB 1.2 MB/s eta 0:00:07
# ...

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np 
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import pandas as pd
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py:46
#      38     _module = _err.name
#      39     raise ImportError(
#      40         f"C extension: {_module} not built. If you want to import "
#      41         "pandas from the source directory, you may need to run "
#      42         "'python -m pip install -ve . --no-build-isolation -Ceditable-verbose=true' "
#      43         "to build the C extensions first."
#      44     ) from _err
# ---> 46 from pandas._config import (
#      47     get_option,
#      48     set_option,
#      49     reset_option,
#      50     describe_option,
# ...

# %%
df
